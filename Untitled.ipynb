# %%
import numpy as np
import pandas as pd
from meshparty import meshwork, trimesh_vtk
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_feather('data_frame1.feather')
df
# Out:
#        Neuron_1  Neuron_2  0-1  1-2  2-3  3-4  4-5
# 0             0         1    0    4    8    8   17
# 1             0         2    0    0    0    0    0
# 2             0         3    0    0    0    0    0
# 3             0         4    0    0    0    0    0
# 4             0         5    0    2    2    7    7
# ...         ...       ...  ...  ...  ...  ...  ...
# 13361       160       162    3   16   28   20   21
# 13362       160       163    0    0    0    0    0
# 13363       161       162    0   12    5    7    3
# 13364       161       163    0    3   23   24   37
# 13365       162       163    0    0    2    4    2
#
# [13366 rows x 7 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13366 entries, 0 to 13365
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Neuron_1  13366 non-null  int64
#  1   Neuron_2  13366 non-null  int64
#  2   0-1       13366 non-null  int64
#  3   1-2       13366 non-null  int64
#  4   2-3       13366 non-null  int64
#  5   3-4       13366 non-null  int64
#  6   4-5       13366 non-null  int64
# dtypes: int64(7)
# memory usage: 731.1 KB
# None

# %%
df1 = pd.read_feather('FinalDataset.feather')
df1
# Out:
#        Nrn 1  Nrn 2  Min Distance        Seg ID Nrn 1        Seg ID Nrn 2  \
# 0          0      1      1.247282  864691135012644086  864691135013235606
# 1          0      2    211.310281  864691135012644086  864691135058985115
# 2          0      3    219.970628  864691135012644086  864691135082074103
# 3          0      4    337.466055  864691135012644086  864691135082074359
# 4          0      5      1.397254  864691135012644086  864691135100167712
# ...      ...    ...           ...                 ...                 ...
# 13361    160    162      0.759537  864691137020057710  864691137053995126
# 13362    160    163      6.697735  864691137020057710  864691137197329985
# 13363    161    162      1.139094  864691137053906294  864691137053995126
# 13364    161    163      1.533769  864691137053906294  864691137197329985
# 13365    162    163      2.886016  864691137053995126  864691137197329985
#
#                          Coordinates  # Interactions < 5 Microns  \
# ...

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13366 entries, 0 to 13365
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Nrn 1                       13366 non-null  int64
#  1   Nrn 2                       13366 non-null  int64
#  2   Min Distance                13366 non-null  float64
#  3   Seg ID Nrn 1                13366 non-null  object
#  4   Seg ID Nrn 2                13366 non-null  object
#  5   Coordinates                 13366 non-null  object
#  6   # Interactions < 5 Microns  13366 non-null  int64
#  7   predicted_MET-type Label_x  13366 non-null  object
#  8   predicted_MET-type Label_y  13366 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 939.9+ KB
# None

# %%
DistanceRange = pd.merge(df, df1, left_on = 'Neuron_1', right_on = 'Nrn 1', how = 'left')
df2 = pd.DataFrame(DistanceRange, columns=['Neuron_1', 'Neuron_2', 'Nrn 1', 'Nrn 2', '0-1', '1-2', '2-3', '3-4', '4-5', '# Interactions < 5 Microns', 'Seg ID Nrn 1', 'Seg ID Nrn 2', 'predicted_MET-type Label_x', 'predicted_MET-type Label_y'])
print(df2.head(10))
# Out:
#    Neuron_1  Neuron_2  Nrn 1  Nrn 2  0-1  1-2  2-3  3-4  4-5  \
# 0         0         1      0      1    0    4    8    8   17
# 1         0         1      0      2    0    4    8    8   17
# 2         0         1      0      3    0    4    8    8   17
# 3         0         1      0      4    0    4    8    8   17
# 4         0         1      0      5    0    4    8    8   17
# 5         0         1      0      6    0    4    8    8   17
# 6         0         1      0      7    0    4    8    8   17
# 7         0         1      0      8    0    4    8    8   17
# 8         0         1      0      9    0    4    8    8   17
# 9         0         1      0     10    0    4    8    8   17
#
#    # Interactions < 5 Microns        Seg ID Nrn 1        Seg ID Nrn 2  \
# 0                          37  864691135012644086  864691135013235606
# 1                           0  864691135012644086  864691135058985115
# 2                           0  864691135012644086  864691135082074103
# ...

# %%
# Create final dataframe 
df3 = pd.DataFrame(DistanceRange, columns=[ '0-1', '1-2', '2-3', '3-4', '4-5', '# Interactions < 5 Microns', 'predicted_MET-type Label_x', 'predicted_MET-type Label_y'])
df3
# Out:
#          0-1  1-2  2-3  3-4  4-5  # Interactions < 5 Microns  \
# 0          0    4    8    8   17                          37
# 1          0    4    8    8   17                           0
# 2          0    4    8    8   17                           0
# 3          0    4    8    8   17                           0
# 4          0    4    8    8   17                          18
# ...      ...  ...  ...  ...  ...                         ...
# 1456889    0   12    5    7    3                          27
# 1456890    0   12    5    7    3                          87
# 1456891    0    3   23   24   37                          27
# 1456892    0    3   23   24   37                          87
# 1456893    0    0    2    4    2                           8
#
#         predicted_MET-type Label_x predicted_MET-type Label_y
# 0                        Vip-MET-1                Lamp5-MET-1
# 1                        Vip-MET-1                  Sst-MET-6
# ...

# %%
# Plot the data
sns.set_theme(style="whitegrid")
ax = sns.stripplot(data=df3) #, jitter=True
# ax.set(ylim=ylims)
plt.show()
# (x=('0-1','1-2','2-3','3-4','4-5'), y='# Interactions < 5 Microns', hue='predicted_MET-type Label_x',
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [30], in <cell line: 3>()
#       1 # Plot the data
#       2 sns.set_theme(style="whitegrid")
# ----> 3 ax = sns.stripplot(data=df3) #, jitter=True
#       4 # ax.set(ylim=ylims)
#       5 plt.show()
#
# File ~\Anaconda3\envs\snakes\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...
